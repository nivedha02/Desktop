# %% [markdown]
# # Chapter 5
#
# ## **wrap prepective**

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img=cv2.imread(r"C:\Users\admin\Pictures\cards.jfif")

image = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) #look at the clr in the below second code the color is bit off..becoz it reads BGR clr in opencv,this happens when we use matplot.this will not happen when we open in a screen in opencv with cv2 function itself.
#so to plot it here itself,we need to change the color.

#cv2.imshow("image",img) #to show imag in different window with computer vision(cv2)
plt.imshow(image) #to show img in the same window as a plot of graph with matplot library(plt)
#cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3896/1192189720.py in <module>
#       5 #img=cv2.imread(r"C:\Users\admin\Pictures\cards.jfif")
#       6 img=cv2.imread("images\naruto.jpg")
# ----> 7 image = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) #look at the clr in the below second code the color is bit off..becoz it reads BGR clr in opencv,this happens when we use matplot.this will not happen when we open in a screen in opencv with cv2 function itself.
#       8 #so to plot it here itself,we need to change the color.
#       9
#
# error: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-1hfhc_rd\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img=cv2.imread(r"C:\Users\admin\Pictures\cards.jfif") #from above code

width,height=250,350 #width and the height of the picture we want
points1=np.float32([ [747,127],[1119,269],[515,681],[859,837] ])
points2=np.float32([ [0,0],[width,0],[0,height],[width,height] ])
matrix=cv2.getPerspectiveTransform(points1,points2)
imageoutput=cv2.warpPerspective(img,matrix,(width,height))
#cv2.imshow("output",imageoutput)
#cv2.imshow("original",img)
#cv2.waitKey(0)
     #------------------------x------------------------x-------------------x-------------------------------------#

#the below code is entirely for matplot :-)


# create figure
fig = plt.figure(figsize=(10, 7))
  
# setting values to rows and column variables
rows = 2
columns = 2

# Adds a subplot at the 1st position
fig.add_subplot(rows, columns, 1)



#with matplot
plt.imshow(imageoutput)
plt.axis("off") #to hide axis
plt.title("output") #to add tittle
 
# Adds a subplot at the 1st position
fig.add_subplot(rows, columns, 2)
plt.imshow(img)
plt.axis("off")
plt.title("original")
# Out:
# Text(0.5, 1.0, 'original')
